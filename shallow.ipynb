# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf

import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from keras.layers import Dense, Activation, Dropout, Flatten

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Conv2D, MaxPooling2D,BatchNormalization
import os
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

#variables
num_classes = 7 #angry, disgust, fear, happy, sad, surprise, neutral
batch_size = 110
epochs = 100
#------------------------------
#read kaggle facial expression recognition challenge dataset (fer2013.csv)
#https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge

with open("/content/drive/MyDrive/fer2013.csv") as f:
  content = f.readlines()

lines = np.array(content)

num_of_instances = lines.size
print("number of instances: ",num_of_instances)
print("instance length: ",len(lines[1].split(",")[1].split(" ")))

#------------------------------
#initialize trainset and test set
x_train, y_train, x_test, y_test = [], [], [], []

#------------------------------
#transfer train and test set data
for i in range(1,num_of_instances):
    try:
        emotion, img, usage = lines[i].split(",")
          
        val = img.split(" ")
            
        pixels = np.array(val, 'float32')
        
        emotion = keras.utils.to_categorical(emotion, num_classes)
    
        if 'Training' in usage:
            y_train.append(emotion)
            x_train.append(pixels)
        elif 'PublicTest' in usage:
            y_test.append(emotion)
            x_test.append(pixels)
    except:
      print("", end="")

#------------------------------
#data transformation for train and test sets
x_train = np.array(x_train, 'float32')
y_train = np.array(y_train, 'float32')
x_test = np.array(x_test, 'float32')
y_test = np.array(y_test, 'float32')

x_train /= 255 #normalize inputs between [0, 1]
x_test /= 255

x_train = x_train.reshape(x_train.shape[0], 48, 48, 1)
x_train = x_train.astype('float32')
x_test = x_test.reshape(x_test.shape[0], 48, 48, 1)
x_test = x_test.astype('float32')

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
#------------------------------
#construct CNN structure
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(48,48,1), strides=1))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))


model.add(Conv2D(64, (3, 3), strides = 1))
model.add(Dropout(0.25))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))



model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

model.add(Dense(512))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))


model.add(Dense(num_classes, activation='softmax'))

#------------------------------
#batch process
gen = ImageDataGenerator()
train_generator = gen.flow(x_train, y_train, batch_size=batch_size)

#------------------------------

model.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

#------------------------------
model.summary()

fit = True

if fit == True:
	#model.fit_generator(x_train, y_train, epochs=epochs) #train for all trainset
	model.fit(train_generator, steps_per_epoch=batch_size, epochs=epochs) #train for randomly selected one
else:
	model.load_weights('/data/facial_expression_model_weights.h5') #load weights
	
#------------------------------
"""
#overall evaluation
score = model.evaluate(x_test, y_test)
print('Test loss:', score[0])
print('Test accuracy:', 100*score[1])
"""
#------------------------------
#function for drawing bar chart for emotion preditions
def emotion_analysis(emotions):
    objects = ('angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral')
    y_pos = np.arange(len(objects))
    
    plt.bar(y_pos, emotions, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')
    
    plt.show()
#------------------------------
# Out:
# number of instances:  35888
# instance length:  2304
# 28709 train samples
# 3589 test samples
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 32)        320
# _________________________________________________________________
# activation (Activation)      (None, 46, 46, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 46, 46, 32)        128
# _________________________________________________________________
# dropout (Dropout)            (None, 46, 46, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 44, 64)        18496
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 44, 44, 64)        0
# _________________________________________________________________
# activation_1 (Activation)    (None, 44, 44, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 44, 44, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               15860224
# _________________________________________________________________
# activation_2 (Activation)    (None, 512)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 3591
# =================================================================
# Total params: 15,885,063
# Trainable params: 15,883,847
# Non-trainable params: 1,216
# _________________________________________________________________
# Epoch 1/100
# 110/110 [==============================] - 2s 19ms/step - loss: 2.0163 - accuracy: 0.3204
# Epoch 2/100
# 110/110 [==============================] - 2s 19ms/step - loss: 1.6095 - accuracy: 0.3970
# Epoch 3/100
# 110/110 [==============================] - 2s 19ms/step - loss: 1.4512 - accuracy: 0.4609
# Epoch 4/100
# 110/110 [==============================] - 2s 19ms/step - loss: 1.3608 - accuracy: 0.4909
# Epoch 5/100
# 110/110 [==============================] - 2s 18ms/step - loss: 1.2520 - accuracy: 0.5371
# Epoch 6/100
# 110/110 [==============================] - 2s 19ms/step - loss: 1.2036 - accuracy: 0.5574
# Epoch 7/100
# 110/110 [==============================] - 2s 19ms/step - loss: 1.1303 - accuracy: 0.5780
# Epoch 8/100
# 110/110 [==============================] - 2s 19ms/step - loss: 1.0667 - accuracy: 0.6097
# Epoch 9/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.9828 - accuracy: 0.6461
# Epoch 10/100
# 110/110 [==============================] - 2s 18ms/step - loss: 0.9312 - accuracy: 0.6641
# Epoch 11/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.8365 - accuracy: 0.7007
# Epoch 12/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.7415 - accuracy: 0.7442
# Epoch 13/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.6904 - accuracy: 0.7601
# Epoch 14/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.6081 - accuracy: 0.7972
# Epoch 15/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.5803 - accuracy: 0.8044
# Epoch 16/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.4796 - accuracy: 0.8405
# Epoch 17/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.4204 - accuracy: 0.8577
# Epoch 18/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.3867 - accuracy: 0.8721
# Epoch 19/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.3536 - accuracy: 0.8836
# Epoch 20/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.3245 - accuracy: 0.8923
# Epoch 21/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.2889 - accuracy: 0.9051
# Epoch 22/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.2570 - accuracy: 0.9194
# Epoch 23/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.2183 - accuracy: 0.9309
# Epoch 24/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.2084 - accuracy: 0.9329
# Epoch 25/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.1846 - accuracy: 0.9401
# Epoch 26/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.1841 - accuracy: 0.9421
# Epoch 27/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.2007 - accuracy: 0.9359
# Epoch 28/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.1608 - accuracy: 0.9504
# Epoch 29/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.3219 - accuracy: 0.8903
# Epoch 30/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.2762 - accuracy: 0.9055
# Epoch 31/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.1896 - accuracy: 0.9366
# Epoch 32/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.1577 - accuracy: 0.9479
# Epoch 33/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.1594 - accuracy: 0.9479
# Epoch 34/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.1748 - accuracy: 0.9436
# Epoch 35/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.1735 - accuracy: 0.9427
# Epoch 36/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.1236 - accuracy: 0.9599
# Epoch 37/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.1236 - accuracy: 0.9605
# Epoch 38/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.1144 - accuracy: 0.9655
# Epoch 39/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.1039 - accuracy: 0.9694
# Epoch 40/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0943 - accuracy: 0.9708
# Epoch 41/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0941 - accuracy: 0.9732
# Epoch 42/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0897 - accuracy: 0.9739
# Epoch 43/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0902 - accuracy: 0.9708
# Epoch 44/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0903 - accuracy: 0.9698
# Epoch 45/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0840 - accuracy: 0.9748
# Epoch 46/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0739 - accuracy: 0.9793
# Epoch 47/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0747 - accuracy: 0.9781
# Epoch 48/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0756 - accuracy: 0.9778
# Epoch 49/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0662 - accuracy: 0.9786
# Epoch 50/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0817 - accuracy: 0.9748
# Epoch 51/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0794 - accuracy: 0.9767
# Epoch 52/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0764 - accuracy: 0.9764
# Epoch 53/100
# 110/110 [==============================] - 2s 18ms/step - loss: 0.0697 - accuracy: 0.9793
# Epoch 54/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.1224 - accuracy: 0.9629
# Epoch 55/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.1298 - accuracy: 0.9602
# Epoch 56/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0930 - accuracy: 0.9712
# Epoch 57/100
# 110/110 [==============================] - 2s 18ms/step - loss: 0.0902 - accuracy: 0.9726
# Epoch 58/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0753 - accuracy: 0.9769
# Epoch 59/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0711 - accuracy: 0.9782
# Epoch 60/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0757 - accuracy: 0.9767
# Epoch 61/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0679 - accuracy: 0.9793
# Epoch 62/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0638 - accuracy: 0.9801
# Epoch 63/100
# 110/110 [==============================] - 2s 18ms/step - loss: 0.0831 - accuracy: 0.9736
# Epoch 64/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0844 - accuracy: 0.9749
# Epoch 65/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0940 - accuracy: 0.9701
# Epoch 66/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0676 - accuracy: 0.9788
# Epoch 67/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0851 - accuracy: 0.9721
# Epoch 68/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0646 - accuracy: 0.9803
# Epoch 69/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0627 - accuracy: 0.9804
# Epoch 70/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0588 - accuracy: 0.9821
# Epoch 71/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0672 - accuracy: 0.9793
# Epoch 72/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0726 - accuracy: 0.9784
# Epoch 73/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0602 - accuracy: 0.9831
# Epoch 74/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0632 - accuracy: 0.9813
# Epoch 75/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0574 - accuracy: 0.9823
# Epoch 76/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0605 - accuracy: 0.9821
# Epoch 77/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0503 - accuracy: 0.9850
# Epoch 78/100
# 110/110 [==============================] - 2s 18ms/step - loss: 0.0615 - accuracy: 0.9824
# Epoch 79/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0521 - accuracy: 0.9845
# Epoch 80/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0614 - accuracy: 0.9814
# Epoch 81/100
# 110/110 [==============================] - 2s 18ms/step - loss: 0.0596 - accuracy: 0.9819
# Epoch 82/100
# 110/110 [==============================] - 2s 18ms/step - loss: 0.0606 - accuracy: 0.9826
# Epoch 83/100
# 110/110 [==============================] - 2s 18ms/step - loss: 0.0544 - accuracy: 0.9831
# Epoch 84/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0612 - accuracy: 0.9823
# Epoch 85/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0542 - accuracy: 0.9854
# Epoch 86/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0514 - accuracy: 0.9849
# Epoch 87/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0589 - accuracy: 0.9823
# Epoch 88/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0524 - accuracy: 0.9850
# Epoch 89/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0541 - accuracy: 0.9850
# Epoch 90/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0687 - accuracy: 0.9787
# Epoch 91/100
# 110/110 [==============================] - 2s 18ms/step - loss: 0.0610 - accuracy: 0.9824
# Epoch 92/100
# 110/110 [==============================] - 2s 18ms/step - loss: 0.0535 - accuracy: 0.9836
# Epoch 93/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0553 - accuracy: 0.9824
# Epoch 94/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0553 - accuracy: 0.9850
# Epoch 95/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0567 - accuracy: 0.9831
# Epoch 96/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0921 - accuracy: 0.9723
# Epoch 97/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0682 - accuracy: 0.9779
# Epoch 98/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0658 - accuracy: 0.9807
# Epoch 99/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0479 - accuracy: 0.9850
# Epoch 100/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0545 - accuracy: 0.9840

# %%
#Saving the model
model.save('model25.h5')

# %%
#Evaluation
train_score = model.evaluate(x_train, y_train, verbose=0)
print('Train loss:', train_score[0])
print('Train accuracy:', 100*train_score[1])
 
test_score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', test_score[0])
print('Test accuracy:', 100*test_score[1])
# Out:
# Train loss: 0.16695891320705414
# Train accuracy: 95.24887800216675
# Test loss: 3.618696451187134
# Test accuracy: 49.48453605175018

# %%
monitor_testset_results = True

if monitor_testset_results == True:
	#make predictions for test set
	predictions = model.predict(x_test)

	index = 0
	for i in predictions:
		if index < 30 and index >= 20:
			#print(i) #predicted scores
			#print(y_test[index]) #actual scores
			
			testing_img = np.array(x_test[index], 'float32')
			testing_img = testing_img.reshape([48, 48]);
			
			plt.gray()
			plt.imshow(testing_img)
			plt.show()
			
			print(i)
			
			emotion_analysis(i)
			print("----------------------------------------------")
		index = index + 1
# Out:
# [9.9732143e-01 9.0863651e-08 1.2477303e-06 1.6342915e-04 2.4518510e-03
#  1.8322057e-06 6.0154627e-05]
# ----------------------------------------------
# [5.4693568e-02 3.0169329e-07 9.0934400e-04 3.0981890e-05 5.9690410e-01
#  1.7940359e-04 3.4728232e-01]
# ----------------------------------------------
# [9.9102366e-01 1.2000930e-07 6.7923618e-03 1.3534457e-03 5.3965067e-04
#  7.1919322e-07 2.9007159e-04]
# ----------------------------------------------
# [1.4120102e-04 2.3239867e-12 9.9106498e-02 6.8580818e-01 2.1429440e-01
#  2.7650415e-07 6.4949744e-04]
# ----------------------------------------------
# [4.1996725e-02 3.2179742e-03 3.2308832e-04 7.1928072e-01 6.8074539e-03
#  9.1282373e-06 2.2836490e-01]
# ----------------------------------------------
# [1.5708825e-03 1.9674923e-07 1.6101462e-01 1.5021297e-06 1.5647195e-01
#  2.2752847e-06 6.8093860e-01]
# ----------------------------------------------
# [7.7191129e-05 1.1385103e-09 3.6997064e-03 9.8853707e-01 7.6755858e-03
#  2.4778993e-10 1.0511040e-05]
# ----------------------------------------------
# [2.0539097e-16 0.0000000e+00 1.0000000e+00 1.0434731e-34 6.4359322e-22
#  0.0000000e+00 1.9680803e-16]
# ----------------------------------------------
# [4.8123756e-01 4.2290040e-04 1.2746407e-03 3.0902734e-01 8.5495340e-05
#  2.0791367e-01 3.8398273e-05]
# ----------------------------------------------
# [3.8678456e-11 9.0625541e-08 1.5989461e-03 2.6288128e-05 1.5262771e-06
#  9.9401385e-01 4.3593296e-03]
# ----------------------------------------------

# %%
#Confusion Matrix.

from sklearn.metrics import classification_report, confusion_matrix
 
pred_list = []; actual_list = [];
 
for i in predictions:
 
  pred_list.append(np.argmax(i))
 
for i in y_test:
 
  actual_list.append(np.argmax(i))
 
confusion_matrix(actual_list, pred_list)
# Out:
# array([[216,   2,  68,  82,  59,   6,  34],
#        [ 12,  20,  10,   8,   3,   0,   3],
#        [ 89,   0, 214,  57,  79,  13,  44],
#        [ 56,   0,  70, 699,  36,   8,  26],
#        [140,   0, 123,  98, 211,   6,  75],
#        [ 36,   0,  98,  39,  18, 207,  17],
#        [ 88,   0,  91, 129,  86,   4, 209]])
