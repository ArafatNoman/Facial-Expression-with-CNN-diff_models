# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf

import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from keras.layers import Dense, Activation, Dropout, Flatten

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt

#variables
num_classes = 7 #angry, disgust, fear, happy, sad, surprise, neutral
batch_size = 110
epochs = 100
#------------------------------
#read kaggle facial expression recognition challenge dataset (fer2013.csv)
#https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge

with open("/content/drive/My Drive/Colab Notebooks/fer2013/fer2013.csv") as f:
  content = f.readlines()

lines = np.array(content)

num_of_instances = lines.size
print("number of instances: ",num_of_instances)
print("instance length: ",len(lines[1].split(",")[1].split(" ")))

#------------------------------
#initialize trainset and test set
x_train, y_train, x_test, y_test = [], [], [], []

#------------------------------
#transfer train and test set data
for i in range(1,num_of_instances):
    try:
        emotion, img, usage = lines[i].split(",")
          
        val = img.split(" ")
            
        pixels = np.array(val, 'float32')
        
        emotion = keras.utils.to_categorical(emotion, num_classes)
    
        if 'Training' in usage:
            y_train.append(emotion)
            x_train.append(pixels)
        elif 'PublicTest' in usage:
            y_test.append(emotion)
            x_test.append(pixels)
    except:
      print("", end="")

#------------------------------
#data transformation for train and test sets
x_train = np.array(x_train, 'float32')
y_train = np.array(y_train, 'float32')
x_test = np.array(x_test, 'float32')
y_test = np.array(y_test, 'float32')

x_train /= 255 #normalize inputs between [0, 1]
x_test /= 255

x_train = x_train.reshape(x_train.shape[0], 48, 48, 1)
x_train = x_train.astype('float32')
x_test = x_test.reshape(x_test.shape[0], 48, 48, 1)
x_test = x_test.astype('float32')

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
#------------------------------
#construct CNN structure
model = Sequential()

#1st convolution layer
model.add(Conv2D(64, (5, 5), activation='relu', input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(5,5), strides=(2, 2)))

#2nd convolution layer
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(3,3), strides=(2, 2)))

#3rd convolution layer
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(AveragePooling2D(pool_size=(3,3), strides=(2, 2)))

model.add(Flatten())

#fully connected neural networks
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(num_classes, activation='softmax'))
#------------------------------
#batch process
gen = ImageDataGenerator()
train_generator = gen.flow(x_train, y_train, batch_size=batch_size)

#------------------------------

model.compile(loss='categorical_crossentropy'
    , optimizer=keras.optimizers.Adam()
    , metrics=['accuracy']
)

#------------------------------

fit = True

if fit == True:
	#model.fit_generator(x_train, y_train, epochs=epochs) #train for all trainset
	model.fit_generator(train_generator, steps_per_epoch=batch_size, epochs=epochs) #train for randomly selected one
else:
	model.load_weights('/data/facial_expression_model_weights.h5') #load weights
	
#------------------------------
"""
#overall evaluation
score = model.evaluate(x_test, y_test)
print('Test loss:', score[0])
print('Test accuracy:', 100*score[1])
"""
#------------------------------
#function for drawing bar chart for emotion preditions
def emotion_analysis(emotions):
    objects = ('angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral')
    y_pos = np.arange(len(objects))
    
    plt.bar(y_pos, emotions, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')
    
    plt.show()
#------------------------------
# Out:
# number of instances:  35888
# instance length:  2304
# 28709 train samples
# 3589 test samples
# WARNING:tensorflow:From <ipython-input-3-f28e84ad41de>:118: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 110/110 [==============================] - 1s 10ms/step - loss: 1.8238 - accuracy: 0.2431
# Epoch 2/100
# 110/110 [==============================] - 1s 10ms/step - loss: 1.8171 - accuracy: 0.2485
# Epoch 3/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.7758 - accuracy: 0.2633
# Epoch 4/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.7104 - accuracy: 0.3017
# Epoch 5/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.6550 - accuracy: 0.3414
# Epoch 6/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.5866 - accuracy: 0.3714
# Epoch 7/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.5335 - accuracy: 0.3960
# Epoch 8/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.5013 - accuracy: 0.4116
# Epoch 9/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.4585 - accuracy: 0.4312
# Epoch 10/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.4146 - accuracy: 0.4507
# Epoch 11/100
# 110/110 [==============================] - 1s 10ms/step - loss: 1.3921 - accuracy: 0.4574
# Epoch 12/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.3566 - accuracy: 0.4830
# Epoch 13/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.3380 - accuracy: 0.4857
# Epoch 14/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.3165 - accuracy: 0.4936
# Epoch 15/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.2988 - accuracy: 0.5048
# Epoch 16/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.2687 - accuracy: 0.5141
# Epoch 17/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.2523 - accuracy: 0.5230
# Epoch 18/100
# 110/110 [==============================] - 1s 10ms/step - loss: 1.2275 - accuracy: 0.5338
# Epoch 19/100
# 110/110 [==============================] - 1s 10ms/step - loss: 1.2196 - accuracy: 0.5374
# Epoch 20/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.2021 - accuracy: 0.5377
# Epoch 21/100
# 110/110 [==============================] - 1s 10ms/step - loss: 1.1838 - accuracy: 0.5473
# Epoch 22/100
# 110/110 [==============================] - 1s 10ms/step - loss: 1.1914 - accuracy: 0.5467
# Epoch 23/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.1474 - accuracy: 0.5616
# Epoch 24/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.1349 - accuracy: 0.5651
# Epoch 25/100
# 110/110 [==============================] - 1s 10ms/step - loss: 1.1399 - accuracy: 0.5690
# Epoch 26/100
# 110/110 [==============================] - 1s 10ms/step - loss: 1.1153 - accuracy: 0.5764
# Epoch 27/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.1011 - accuracy: 0.5826
# Epoch 28/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.0829 - accuracy: 0.5910
# Epoch 29/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.0863 - accuracy: 0.5916
# Epoch 30/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.0894 - accuracy: 0.5889
# Epoch 31/100
# 110/110 [==============================] - 1s 10ms/step - loss: 1.0758 - accuracy: 0.5875
# Epoch 32/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.0356 - accuracy: 0.6024
# Epoch 33/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.0278 - accuracy: 0.6091
# Epoch 34/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.0127 - accuracy: 0.6167
# Epoch 35/100
# 110/110 [==============================] - 1s 9ms/step - loss: 1.0141 - accuracy: 0.6159
# Epoch 36/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.9937 - accuracy: 0.6278
# Epoch 37/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.9892 - accuracy: 0.6291
# Epoch 38/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.9630 - accuracy: 0.6353
# Epoch 39/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.9615 - accuracy: 0.6384
# Epoch 40/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.9366 - accuracy: 0.6500
# Epoch 41/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.9366 - accuracy: 0.6435
# Epoch 42/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.9081 - accuracy: 0.6567
# Epoch 43/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.9099 - accuracy: 0.6614
# Epoch 44/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.8973 - accuracy: 0.6593
# Epoch 45/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.8696 - accuracy: 0.6736
# Epoch 46/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.8638 - accuracy: 0.6816
# Epoch 47/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.8456 - accuracy: 0.6853
# Epoch 48/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.8248 - accuracy: 0.6931
# Epoch 49/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.8154 - accuracy: 0.6967
# Epoch 50/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.8007 - accuracy: 0.7008
# Epoch 51/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.8004 - accuracy: 0.7012
# Epoch 52/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.7973 - accuracy: 0.7050
# Epoch 53/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.7728 - accuracy: 0.7081
# Epoch 54/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.7487 - accuracy: 0.7209
# Epoch 55/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.7420 - accuracy: 0.7262
# Epoch 56/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.7203 - accuracy: 0.7333
# Epoch 57/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.6905 - accuracy: 0.7483
# Epoch 58/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.6749 - accuracy: 0.7518
# Epoch 59/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.6801 - accuracy: 0.7511
# Epoch 60/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.6671 - accuracy: 0.7517
# Epoch 61/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.6546 - accuracy: 0.7605
# Epoch 62/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.6510 - accuracy: 0.7581
# Epoch 63/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.6352 - accuracy: 0.7669
# Epoch 64/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.6196 - accuracy: 0.7692
# Epoch 65/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.6001 - accuracy: 0.7805
# Epoch 66/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.5899 - accuracy: 0.7829
# Epoch 67/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.5647 - accuracy: 0.7949
# Epoch 68/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.5529 - accuracy: 0.7986
# Epoch 69/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.5570 - accuracy: 0.7922
# Epoch 70/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.5370 - accuracy: 0.8035
# Epoch 71/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.5309 - accuracy: 0.8046
# Epoch 72/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.5215 - accuracy: 0.8088
# Epoch 73/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.5097 - accuracy: 0.8144
# Epoch 74/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.5002 - accuracy: 0.8169
# Epoch 75/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.4939 - accuracy: 0.8162
# Epoch 76/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.4724 - accuracy: 0.8271
# Epoch 77/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.4600 - accuracy: 0.8354
# Epoch 78/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.4518 - accuracy: 0.8339
# Epoch 79/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.4458 - accuracy: 0.8367
# Epoch 80/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.4356 - accuracy: 0.8397
# Epoch 81/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.4223 - accuracy: 0.8443
# Epoch 82/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.4102 - accuracy: 0.8552
# Epoch 83/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.4010 - accuracy: 0.8561
# Epoch 84/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.4147 - accuracy: 0.8468
# Epoch 85/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.3620 - accuracy: 0.8701
# Epoch 86/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.3923 - accuracy: 0.8583
# Epoch 87/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.3644 - accuracy: 0.8673
# Epoch 88/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.3832 - accuracy: 0.8636
# Epoch 89/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.3388 - accuracy: 0.8781
# Epoch 90/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.3552 - accuracy: 0.8677
# Epoch 91/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.3276 - accuracy: 0.8807
# Epoch 92/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.3360 - accuracy: 0.8786
# Epoch 93/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.2989 - accuracy: 0.8934
# Epoch 94/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.3224 - accuracy: 0.8820
# Epoch 95/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.3099 - accuracy: 0.8894
# Epoch 96/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.3144 - accuracy: 0.8867
# Epoch 97/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.3194 - accuracy: 0.8835
# Epoch 98/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.2987 - accuracy: 0.8909
# Epoch 99/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.2966 - accuracy: 0.8947
# Epoch 100/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.3008 - accuracy: 0.8903

# %%
#Saving the model
model.save('model25.h5')

# %%
#Evaluation
train_score = model.evaluate(x_train, y_train, verbose=0)
print('Train loss:', train_score[0])
print('Train accuracy:', 100*train_score[1])
 
test_score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', test_score[0])
print('Test accuracy:', 100*test_score[1])
# Out:
# Train loss: 0.1949130892753601
# Train accuracy: 93.24601888656616
# Test loss: 2.2976629734039307
# Test accuracy: 55.64224123954773

# %%
monitor_testset_results = True

if monitor_testset_results == True:
	#make predictions for test set
	predictions = model.predict(x_test)

	index = 0
	for i in predictions:
		if index < 30 and index >= 20:
			#print(i) #predicted scores
			#print(y_test[index]) #actual scores
			
			testing_img = np.array(x_test[index], 'float32')
			testing_img = testing_img.reshape([48, 48]);
			
			plt.gray()
			plt.imshow(testing_img)
			plt.show()
			
			print(i)
			
			emotion_analysis(i)
			print("----------------------------------------------")
		index = index + 1
# Out:
# [0.0216362  0.00194893 0.02259062 0.68730986 0.18936475 0.06273637
#  0.01441329]
# ----------------------------------------------
# [2.4841032e-08 2.6760464e-15 4.5008672e-08 6.9366088e-08 5.9331667e-10
#  9.9999988e-01 8.7831986e-10]
# ----------------------------------------------
# [9.7362399e-01 1.4927930e-05 5.5412308e-04 6.0457569e-06 2.4478229e-02
#  5.4792247e-07 1.3221138e-03]
# ----------------------------------------------
# [4.5838755e-05 9.1820024e-10 2.7578861e-01 2.8879109e-07 6.9136351e-01
#  1.7214181e-06 3.2800030e-02]
# ----------------------------------------------
# [3.7270656e-01 7.5474154e-04 6.3018752e-03 1.3050959e-04 6.1825305e-01
#  5.3882155e-07 1.8527894e-03]
# ----------------------------------------------
# [0.5489055  0.01209105 0.05717877 0.0126345  0.25411737 0.00411572
#  0.11095708]
# ----------------------------------------------
# [1.5997478e-01 1.5586468e-04 1.1574443e-01 1.0385832e-05 7.2198337e-01
#  2.7419171e-06 2.1283452e-03]
# ----------------------------------------------
# [9.0436057e-05 1.9042000e-13 7.3546607e-06 8.8441084e-05 6.2136423e-02
#  6.9457458e-09 9.3767738e-01]
# ----------------------------------------------
# [2.6338032e-02 4.3627160e-09 2.1419097e-03 1.6752270e-04 3.3083913e-06
#  9.7134912e-01 9.8127408e-09]
# ----------------------------------------------
# [4.1162584e-09 9.7255063e-14 2.4474736e-03 4.7404964e-09 7.4111387e-07
#  9.9755186e-01 3.4653045e-13]
# ----------------------------------------------

# %%
#Confusion Matrix.

from sklearn.metrics import classification_report, confusion_matrix
 
pred_list = []; actual_list = [];
 
for i in predictions:
 
  pred_list.append(np.argmax(i))
 
for i in y_test:
 
  actual_list.append(np.argmax(i))
 
confusion_matrix(actual_list, pred_list)
# Out:
# array([[228,  12,  50,  24,  79,  15,  59],
#        [ 10,  27,   3,   1,   8,   0,   7],
#        [ 54,   4, 180,  22, 104,  57,  75],
#        [ 42,   3,  41, 654,  51,  30,  74],
#        [ 88,   4,  86,  40, 294,  17, 124],
#        [  5,   3,  58,  15,   9, 308,  17],
#        [ 38,   4,  49,  56, 138,  16, 306]])
