# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf

import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from keras.layers import Dense, Activation, Dropout, Flatten

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Conv2D, MaxPooling2D,BatchNormalization
import os
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

#variables
num_classes = 7 #angry, disgust, fear, happy, sad, surprise, neutral
batch_size = 110
epochs = 100
#------------------------------
#read kaggle facial expression recognition challenge dataset (fer2013.csv)
#https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge

with open("/content/drive/MyDrive/fer2013.csv") as f:
  content = f.readlines()

lines = np.array(content)

num_of_instances = lines.size
print("number of instances: ",num_of_instances)
print("instance length: ",len(lines[1].split(",")[1].split(" ")))

#------------------------------
#initialize trainset and test set
x_train, y_train, x_test, y_test = [], [], [], []

#------------------------------
#transfer train and test set data
for i in range(1,num_of_instances):
    try:
        emotion, img, usage = lines[i].split(",")
          
        val = img.split(" ")
            
        pixels = np.array(val, 'float32')
        
        emotion = keras.utils.to_categorical(emotion, num_classes)
    
        if 'Training' in usage:
            y_train.append(emotion)
            x_train.append(pixels)
        elif 'PublicTest' in usage:
            y_test.append(emotion)
            x_test.append(pixels)
    except:
      print("", end="")

#------------------------------
#data transformation for train and test sets
x_train = np.array(x_train, 'float32')
y_train = np.array(y_train, 'float32')
x_test = np.array(x_test, 'float32')
y_test = np.array(y_test, 'float32')

x_train /= 255 #normalize inputs between [0, 1]
x_test /= 255

x_train = x_train.reshape(x_train.shape[0], 48, 48, 1)
x_train = x_train.astype('float32')
x_test = x_test.reshape(x_test.shape[0], 48, 48, 1)
x_test = x_test.astype('float32')

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
#------------------------------
#construct CNN structure
model = Sequential()
model.add(Conv2D(64, (3, 3), input_shape=(48,48,1)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3)))
model.add(Dropout(0.3))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

model.add(Dense(128))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(64))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Dense(num_classes, activation='softmax'))

#------------------------------
#batch process
gen = ImageDataGenerator()
train_generator = gen.flow(x_train, y_train, batch_size=batch_size)

#------------------------------

model.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

#------------------------------
model.summary()

fit = True

if fit == True:
	#model.fit_generator(x_train, y_train, epochs=epochs) #train for all trainset
	model.fit(train_generator, steps_per_epoch=batch_size, epochs=epochs) #train for randomly selected one
else:
	model.load_weights('/data/facial_expression_model_weights.h5') #load weights
	
#------------------------------
"""
#overall evaluation
score = model.evaluate(x_test, y_test)
print('Test loss:', score[0])
print('Test accuracy:', 100*score[1])
"""
#------------------------------
#function for drawing bar chart for emotion preditions
def emotion_analysis(emotions):
    objects = ('angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral')
    y_pos = np.arange(len(objects))
    
    plt.bar(y_pos, emotions, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')
    
    plt.show()
#------------------------------
# Out:
# number of instances:  35888
# instance length:  2304
# 28709 train samples
# 3589 test samples
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 46, 46, 64)        640
# _________________________________________________________________
# activation_18 (Activation)   (None, 46, 46, 64)        0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 46, 46, 64)        256
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 21, 21, 128)       73856
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 21, 21, 128)       0
# _________________________________________________________________
# activation_19 (Activation)   (None, 21, 21, 128)       0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 21, 21, 128)       512
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# activation_20 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 2, 2, 256)         590080
# _________________________________________________________________
# activation_21 (Activation)   (None, 2, 2, 256)         0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 2, 2, 256)         1024
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               32896
# _________________________________________________________________
# activation_22 (Activation)   (None, 128)               0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                8256
# _________________________________________________________________
# activation_23 (Activation)   (None, 64)                0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 64)                256
# _________________________________________________________________
# dense_14 (Dense)             (None, 7)                 455
# =================================================================
# Total params: 1,004,935
# Trainable params: 1,003,143
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/100
# 110/110 [==============================] - 3s 23ms/step - loss: 1.8881 - accuracy: 0.2846
# Epoch 2/100
# 110/110 [==============================] - 2s 23ms/step - loss: 1.5446 - accuracy: 0.4097
# Epoch 3/100
# 110/110 [==============================] - 2s 23ms/step - loss: 1.4125 - accuracy: 0.4597
# Epoch 4/100
# 110/110 [==============================] - 2s 23ms/step - loss: 1.3144 - accuracy: 0.4996
# Epoch 5/100
# 110/110 [==============================] - 2s 22ms/step - loss: 1.2551 - accuracy: 0.5240
# Epoch 6/100
# 110/110 [==============================] - 2s 23ms/step - loss: 1.1823 - accuracy: 0.5516
# Epoch 7/100
# 110/110 [==============================] - 2s 23ms/step - loss: 1.1500 - accuracy: 0.5699
# Epoch 8/100
# 110/110 [==============================] - 2s 23ms/step - loss: 1.0870 - accuracy: 0.5886
# Epoch 9/100
# 110/110 [==============================] - 3s 23ms/step - loss: 1.0404 - accuracy: 0.6095
# Epoch 10/100
# 110/110 [==============================] - 2s 23ms/step - loss: 1.0061 - accuracy: 0.6294
# Epoch 11/100
# 110/110 [==============================] - 2s 23ms/step - loss: 0.9706 - accuracy: 0.6391
# Epoch 12/100
# 110/110 [==============================] - 2s 23ms/step - loss: 0.9294 - accuracy: 0.6558
# Epoch 13/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.8764 - accuracy: 0.6739
# Epoch 14/100
# 110/110 [==============================] - 2s 23ms/step - loss: 0.8421 - accuracy: 0.6924
# Epoch 15/100
# 110/110 [==============================] - 2s 23ms/step - loss: 0.7939 - accuracy: 0.7060
# Epoch 16/100
# 110/110 [==============================] - 2s 23ms/step - loss: 0.7534 - accuracy: 0.7287
# Epoch 17/100
# 110/110 [==============================] - 2s 23ms/step - loss: 0.7192 - accuracy: 0.7409
# Epoch 18/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.6561 - accuracy: 0.7637
# Epoch 19/100
# 110/110 [==============================] - 2s 23ms/step - loss: 0.6134 - accuracy: 0.7840
# Epoch 20/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.5954 - accuracy: 0.7888
# Epoch 21/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.5377 - accuracy: 0.8114
# Epoch 22/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.5077 - accuracy: 0.8220
# Epoch 23/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.4696 - accuracy: 0.8378
# Epoch 24/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.4246 - accuracy: 0.8485
# Epoch 25/100
# 110/110 [==============================] - 2s 23ms/step - loss: 0.4127 - accuracy: 0.8567
# Epoch 26/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.3646 - accuracy: 0.8776
# Epoch 27/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.3479 - accuracy: 0.8796
# Epoch 28/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.3334 - accuracy: 0.8871
# Epoch 29/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.3028 - accuracy: 0.8969
# Epoch 30/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.2788 - accuracy: 0.9045
# Epoch 31/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.2637 - accuracy: 0.9072
# Epoch 32/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.2335 - accuracy: 0.9211
# Epoch 33/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.2410 - accuracy: 0.9184
# Epoch 34/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.2212 - accuracy: 0.9226
# Epoch 35/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.2120 - accuracy: 0.9267
# Epoch 36/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.2299 - accuracy: 0.9217
# Epoch 37/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.2032 - accuracy: 0.9288
# Epoch 38/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1924 - accuracy: 0.9343
# Epoch 39/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1698 - accuracy: 0.9409
# Epoch 40/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1524 - accuracy: 0.9481
# Epoch 41/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1632 - accuracy: 0.9435
# Epoch 42/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1464 - accuracy: 0.9510
# Epoch 43/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1394 - accuracy: 0.9528
# Epoch 44/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1368 - accuracy: 0.9555
# Epoch 45/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1313 - accuracy: 0.9564
# Epoch 46/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1398 - accuracy: 0.9538
# Epoch 47/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1411 - accuracy: 0.9483
# Epoch 48/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1256 - accuracy: 0.9565
# Epoch 49/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1167 - accuracy: 0.9604
# Epoch 50/100
# 110/110 [==============================] - 2s 23ms/step - loss: 0.1270 - accuracy: 0.9567
# Epoch 51/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1279 - accuracy: 0.9578
# Epoch 52/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1130 - accuracy: 0.9598
# Epoch 53/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1072 - accuracy: 0.9649
# Epoch 54/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1213 - accuracy: 0.9581
# Epoch 55/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1066 - accuracy: 0.9634
# Epoch 56/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1026 - accuracy: 0.9670
# Epoch 57/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1049 - accuracy: 0.9649
# Epoch 58/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1109 - accuracy: 0.9622
# Epoch 59/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0987 - accuracy: 0.9686
# Epoch 60/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1147 - accuracy: 0.9621
# Epoch 61/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0984 - accuracy: 0.9659
# Epoch 62/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0847 - accuracy: 0.9713
# Epoch 63/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.1040 - accuracy: 0.9655
# Epoch 64/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0883 - accuracy: 0.9714
# Epoch 65/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0859 - accuracy: 0.9709
# Epoch 66/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0859 - accuracy: 0.9701
# Epoch 67/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0913 - accuracy: 0.9706
# Epoch 68/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0857 - accuracy: 0.9722
# Epoch 69/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0900 - accuracy: 0.9704
# Epoch 70/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0897 - accuracy: 0.9703
# Epoch 71/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0910 - accuracy: 0.9684
# Epoch 72/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0883 - accuracy: 0.9707
# Epoch 73/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0826 - accuracy: 0.9726
# Epoch 74/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0811 - accuracy: 0.9726
# Epoch 75/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0772 - accuracy: 0.9743
# Epoch 76/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0941 - accuracy: 0.9683
# Epoch 77/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0873 - accuracy: 0.9701
# Epoch 78/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0720 - accuracy: 0.9750
# Epoch 79/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0694 - accuracy: 0.9769
# Epoch 80/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0714 - accuracy: 0.9778
# Epoch 81/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0640 - accuracy: 0.9788
# Epoch 82/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0709 - accuracy: 0.9760
# Epoch 83/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0791 - accuracy: 0.9736
# Epoch 84/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0648 - accuracy: 0.9773
# Epoch 85/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0713 - accuracy: 0.9764
# Epoch 86/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0661 - accuracy: 0.9777
# Epoch 87/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0744 - accuracy: 0.9740
# Epoch 88/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0673 - accuracy: 0.9772
# Epoch 89/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0795 - accuracy: 0.9732
# Epoch 90/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0677 - accuracy: 0.9756
# Epoch 91/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0698 - accuracy: 0.9765
# Epoch 92/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0611 - accuracy: 0.9789
# Epoch 93/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0537 - accuracy: 0.9823
# Epoch 94/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0594 - accuracy: 0.9798
# Epoch 95/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0589 - accuracy: 0.9792
# Epoch 96/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0543 - accuracy: 0.9809
# Epoch 97/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0649 - accuracy: 0.9762
# Epoch 98/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0627 - accuracy: 0.9792
# Epoch 99/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0711 - accuracy: 0.9756
# Epoch 100/100
# 110/110 [==============================] - 3s 23ms/step - loss: 0.0699 - accuracy: 0.9757

# %%
#Saving the model
model.save('model25.h5')

# %%
#Evaluation
train_score = model.evaluate(x_train, y_train, verbose=0)
print('Train loss:', train_score[0])
print('Train accuracy:', 100*train_score[1])
 
test_score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', test_score[0])
print('Test accuracy:', 100*test_score[1])
# Out:
# Train loss: 0.06399524211883545
# Train accuracy: 97.7428674697876
# Test loss: 2.3036837577819824
# Test accuracy: 58.17776322364807

# %%
monitor_testset_results = True

if monitor_testset_results == True:
	#make predictions for test set
	predictions = model.predict(x_test)

	index = 0
	for i in predictions:
		if index < 30 and index >= 20:
			#print(i) #predicted scores
			#print(y_test[index]) #actual scores
			
			testing_img = np.array(x_test[index], 'float32')
			testing_img = testing_img.reshape([48, 48]);
			
			plt.gray()
			plt.imshow(testing_img)
			plt.show()
			
			print(i)
			
			emotion_analysis(i)
			print("----------------------------------------------")
		index = index + 1
# Out:
# [5.3416288e-01 1.1753823e-05 5.0866132e-04 3.6090427e-05 1.0885177e-01
#  8.9427497e-04 3.5553458e-01]
# ----------------------------------------------
# [3.8672683e-06 3.9257327e-07 5.2428778e-08 8.0854625e-06 1.4483666e-08
#  9.9998760e-01 5.3904262e-08]
# ----------------------------------------------
# [4.3804827e-01 3.1186955e-04 1.7397340e-05 3.3716203e-03 2.0668928e-02
#  1.1777063e-05 5.3757012e-01]
# ----------------------------------------------
# [4.0383593e-04 3.6952440e-06 1.8939047e-05 7.8491494e-02 8.6311007e-01
#  1.0784902e-06 5.7971019e-02]
# ----------------------------------------------
# [1.3084903e-01 1.3370079e-03 5.0172089e-03 1.7330264e-04 2.4263454e-03
#  1.2404396e-03 8.5895669e-01]
# ----------------------------------------------
# [0.40343237 0.21551175 0.01735577 0.00058531 0.2483903  0.00888385
#  0.10584068]
# ----------------------------------------------
# [2.9459165e-05 4.8040342e-06 1.6016871e-03 9.8751210e-05 9.9415511e-01
#  6.7155514e-07 4.1095456e-03]
# ----------------------------------------------
# [1.7091084e-03 6.2175684e-05 2.4037308e-01 1.8139508e-01 2.1737930e-01
#  3.5899490e-01 8.6355569e-05]
# ----------------------------------------------
# [1.1027016e-02 1.4782275e-06 1.1103611e-04 3.2633462e-04 1.8608433e-05
#  9.8851049e-01 4.9019282e-06]
# ----------------------------------------------
# [3.7841194e-06 3.4967591e-06 1.4731836e-05 4.6507392e-08 1.0200290e-05
#  9.9996090e-01 6.8276217e-06]
# ----------------------------------------------

# %%
#Confusion Matrix.

from sklearn.metrics import classification_report, confusion_matrix
 
pred_list = []; actual_list = [];
 
for i in predictions:
 
  pred_list.append(np.argmax(i))
 
for i in y_test:
 
  actual_list.append(np.argmax(i))
 
confusion_matrix(actual_list, pred_list)
# Out:
# array([[232,   0,  74,  41,  60,  10,  50],
#        [ 35,   0,  13,   4,   2,   0,   2],
#        [ 45,   0, 238,  26,  95,  29,  63],
#        [ 27,   0,  22, 734,  33,  22,  57],
#        [ 81,   0,  93,  48, 325,   9,  97],
#        [ 11,   0,  65,  27,   3, 293,  16],
#        [ 65,   0,  53,  67, 109,   7, 306]])
