# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf

import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from keras.layers import Dense, Activation, Dropout, Flatten

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Conv2D, MaxPooling2D,BatchNormalization
import os
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

#variables
num_classes = 7 #angry, disgust, fear, happy, sad, surprise, neutral
batch_size = 110
epochs = 100
#------------------------------
#read kaggle facial expression recognition challenge dataset (fer2013.csv)
#https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge

with open("/content/drive/MyDrive/fer2013.csv") as f:
  content = f.readlines()

lines = np.array(content)

num_of_instances = lines.size
print("number of instances: ",num_of_instances)
print("instance length: ",len(lines[1].split(",")[1].split(" ")))

#------------------------------
#initialize trainset and test set
x_train, y_train, x_test, y_test = [], [], [], []

#------------------------------
#transfer train and test set data
for i in range(1,num_of_instances):
    try:
        emotion, img, usage = lines[i].split(",")
          
        val = img.split(" ")
            
        pixels = np.array(val, 'float32')
        
        emotion = keras.utils.to_categorical(emotion, num_classes)
    
        if 'Training' in usage:
            y_train.append(emotion)
            x_train.append(pixels)
        elif 'PublicTest' in usage:
            y_test.append(emotion)
            x_test.append(pixels)
    except:
      print("", end="")

#------------------------------
#data transformation for train and test sets
x_train = np.array(x_train, 'float32')
y_train = np.array(y_train, 'float32')
x_test = np.array(x_test, 'float32')
y_test = np.array(y_test, 'float32')

x_train /= 255 #normalize inputs between [0, 1]
x_test /= 255

x_train = x_train.reshape(x_train.shape[0], 48, 48, 1)
x_train = x_train.astype('float32')
x_test = x_test.reshape(x_test.shape[0], 48, 48, 1)
x_test = x_test.astype('float32')

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
#------------------------------
#construct CNN structure
model = Sequential()
model.add(Conv2D(64, (3, 3), input_shape=(48,48,1))) 
model.add(Activation('relu'))
model.add(BatchNormalization()) 
model.add(Dropout(0.25))

model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2)))
model.add(Conv2D(128, (5, 5), strides=1)) 
model.add(Activation('relu')) 
model.add(BatchNormalization()) 
model.add(Dropout(0.25))

model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2))) 
model.add(Conv2D(512, (3, 3), strides=1)) 
model.add(Activation('relu')) 
model.add(BatchNormalization()) 
model.add(Dropout(0.25))

model.add(Conv2D(512, (3, 3), strides=1)) 
model.add(Activation('relu')) 
model.add(BatchNormalization()) 
model.add(Dropout(0.25))

model.add(Flatten()) # this converts our 3D feature maps to 1D feature vectors

model.add(Dense(256)) 
model.add(Activation('relu')) 
model.add(BatchNormalization()) 
model.add(Dropout(0.25))

model.add(Dense(512)) 
model.add(Activation('relu')) 
model.add(BatchNormalization()) 
model.add(Dropout(0.25))

model.add(Dense(num_classes, activation='softmax'))

#------------------------------
#batch process
gen = ImageDataGenerator()
train_generator = gen.flow(x_train, y_train, batch_size=batch_size)

#------------------------------

model.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

#------------------------------
model.summary()

fit = True

if fit == True:
	#model.fit_generator(x_train, y_train, epochs=epochs) #train for all trainset
	model.fit(train_generator, steps_per_epoch=batch_size, epochs=epochs) #train for randomly selected one
else:
	model.load_weights('/data/facial_expression_model_weights.h5') #load weights
	
#------------------------------
"""
#overall evaluation
score = model.evaluate(x_test, y_test)
print('Test loss:', score[0])
print('Test accuracy:', 100*score[1])
"""
#------------------------------
#function for drawing bar chart for emotion preditions
def emotion_analysis(emotions):
    objects = ('angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral')
    y_pos = np.arange(len(objects))
    
    plt.bar(y_pos, emotions, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')
    
    plt.show()
#------------------------------
# Out:
# number of instances:  35888
# instance length:  2304
# 28709 train samples
# 3589 test samples
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 46, 46, 64)        640
# _________________________________________________________________
# activation_6 (Activation)    (None, 46, 46, 64)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 46, 46, 64)        256
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 46, 46, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 19, 19, 128)       204928
# _________________________________________________________________
# activation_7 (Activation)    (None, 19, 19, 128)       0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 19, 19, 128)       512
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 19, 19, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 7, 512)         590336
# _________________________________________________________________
# activation_8 (Activation)    (None, 7, 7, 512)         0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 7, 7, 512)         2048
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 5, 5, 512)         2359808
# _________________________________________________________________
# activation_9 (Activation)    (None, 5, 5, 512)         0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 5, 5, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               3277056
# _________________________________________________________________
# activation_10 (Activation)   (None, 256)               0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               131584
# _________________________________________________________________
# activation_11 (Activation)   (None, 512)               0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 3591
# =================================================================
# Total params: 6,575,879
# Trainable params: 6,571,911
# Non-trainable params: 3,968
# _________________________________________________________________
# Epoch 1/100
# 110/110 [==============================] - 3s 24ms/step - loss: 2.1572 - accuracy: 0.2407
# Epoch 2/100
# 110/110 [==============================] - 3s 26ms/step - loss: 1.7885 - accuracy: 0.3364
# Epoch 3/100
# 110/110 [==============================] - 3s 24ms/step - loss: 1.6220 - accuracy: 0.3974
# Epoch 4/100
# 110/110 [==============================] - 3s 24ms/step - loss: 1.4732 - accuracy: 0.4582
# Epoch 5/100
# 110/110 [==============================] - 3s 24ms/step - loss: 1.3645 - accuracy: 0.4871
# Epoch 6/100
# 110/110 [==============================] - 3s 24ms/step - loss: 1.2846 - accuracy: 0.5293
# Epoch 7/100
# 110/110 [==============================] - 3s 24ms/step - loss: 1.2274 - accuracy: 0.5439
# Epoch 8/100
# 110/110 [==============================] - 3s 24ms/step - loss: 1.1935 - accuracy: 0.5580
# Epoch 9/100
# 110/110 [==============================] - 3s 24ms/step - loss: 1.1267 - accuracy: 0.5777
# Epoch 10/100
# 110/110 [==============================] - 3s 24ms/step - loss: 1.0877 - accuracy: 0.5937
# Epoch 11/100
# 110/110 [==============================] - 3s 24ms/step - loss: 1.0149 - accuracy: 0.6259
# Epoch 12/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.9936 - accuracy: 0.6265
# Epoch 13/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.9488 - accuracy: 0.6493
# Epoch 14/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.9058 - accuracy: 0.6654
# Epoch 15/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.8607 - accuracy: 0.6815
# Epoch 16/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.8308 - accuracy: 0.6969
# Epoch 17/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.7809 - accuracy: 0.7128
# Epoch 18/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.7475 - accuracy: 0.7330
# Epoch 19/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.7119 - accuracy: 0.7372
# Epoch 20/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.6545 - accuracy: 0.7669
# Epoch 21/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.6513 - accuracy: 0.7697
# Epoch 22/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.6155 - accuracy: 0.7775
# Epoch 23/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.5845 - accuracy: 0.7889
# Epoch 24/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.5485 - accuracy: 0.8073
# Epoch 25/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.5063 - accuracy: 0.8165
# Epoch 26/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.4944 - accuracy: 0.8273
# Epoch 27/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.4542 - accuracy: 0.8384
# Epoch 28/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.4279 - accuracy: 0.8495
# Epoch 29/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.4168 - accuracy: 0.8535
# Epoch 30/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.3905 - accuracy: 0.8645
# Epoch 31/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.3701 - accuracy: 0.8660
# Epoch 32/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.3562 - accuracy: 0.8757
# Epoch 33/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.3285 - accuracy: 0.8870
# Epoch 34/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.3376 - accuracy: 0.8798
# Epoch 35/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.3140 - accuracy: 0.8921
# Epoch 36/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.3044 - accuracy: 0.8928
# Epoch 37/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.2751 - accuracy: 0.9029
# Epoch 38/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2839 - accuracy: 0.8974
# Epoch 39/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.2603 - accuracy: 0.9121
# Epoch 40/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.2669 - accuracy: 0.9077
# Epoch 41/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.2519 - accuracy: 0.9100
# Epoch 42/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2395 - accuracy: 0.9138
# Epoch 43/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.2334 - accuracy: 0.9176
# Epoch 44/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.2150 - accuracy: 0.9271
# Epoch 45/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.2026 - accuracy: 0.9288
# Epoch 46/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.2261 - accuracy: 0.9205
# Epoch 47/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.2058 - accuracy: 0.9294
# Epoch 48/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1950 - accuracy: 0.9317
# Epoch 49/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1881 - accuracy: 0.9335
# Epoch 50/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1824 - accuracy: 0.9364
# Epoch 51/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.1899 - accuracy: 0.9335
# Epoch 52/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.1813 - accuracy: 0.9368
# Epoch 53/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.1821 - accuracy: 0.9383
# Epoch 54/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1792 - accuracy: 0.9381
# Epoch 55/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1762 - accuracy: 0.9383
# Epoch 56/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1616 - accuracy: 0.9426
# Epoch 57/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1743 - accuracy: 0.9395
# Epoch 58/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1624 - accuracy: 0.9436
# Epoch 59/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1551 - accuracy: 0.9462
# Epoch 60/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1647 - accuracy: 0.9430
# Epoch 61/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1468 - accuracy: 0.9490
# Epoch 62/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1520 - accuracy: 0.9448
# Epoch 63/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1552 - accuracy: 0.9455
# Epoch 64/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1434 - accuracy: 0.9494
# Epoch 65/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1428 - accuracy: 0.9493
# Epoch 66/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1554 - accuracy: 0.9445
# Epoch 67/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.1541 - accuracy: 0.9461
# Epoch 68/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1440 - accuracy: 0.9493
# Epoch 69/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.1401 - accuracy: 0.9503
# Epoch 70/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.1330 - accuracy: 0.9532
# Epoch 71/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1361 - accuracy: 0.9516
# Epoch 72/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.1303 - accuracy: 0.9559
# Epoch 73/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1369 - accuracy: 0.9500
# Epoch 74/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.1336 - accuracy: 0.9556
# Epoch 75/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1306 - accuracy: 0.9550
# Epoch 76/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1220 - accuracy: 0.9568
# Epoch 77/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.1205 - accuracy: 0.9593
# Epoch 78/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1308 - accuracy: 0.9546
# Epoch 79/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1239 - accuracy: 0.9548
# Epoch 80/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1222 - accuracy: 0.9569
# Epoch 81/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1184 - accuracy: 0.9589
# Epoch 82/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.1204 - accuracy: 0.9569
# Epoch 83/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1146 - accuracy: 0.9607
# Epoch 84/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1233 - accuracy: 0.9583
# Epoch 85/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.1148 - accuracy: 0.9625
# Epoch 86/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1021 - accuracy: 0.9642
# Epoch 87/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.1080 - accuracy: 0.9637
# Epoch 88/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1069 - accuracy: 0.9611
# Epoch 89/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1101 - accuracy: 0.9622
# Epoch 90/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1090 - accuracy: 0.9625
# Epoch 91/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1007 - accuracy: 0.9650
# Epoch 92/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1069 - accuracy: 0.9633
# Epoch 93/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1020 - accuracy: 0.9645
# Epoch 94/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1073 - accuracy: 0.9621
# Epoch 95/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1069 - accuracy: 0.9616
# Epoch 96/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.0991 - accuracy: 0.9658
# Epoch 97/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.0977 - accuracy: 0.9652
# Epoch 98/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.0976 - accuracy: 0.9675
# Epoch 99/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.1042 - accuracy: 0.9648
# Epoch 100/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1036 - accuracy: 0.9665

# %%
#Saving the model
model.save('model25.h5')

# %%
#Evaluation
train_score = model.evaluate(x_train, y_train, verbose=0)
print('Train loss:', train_score[0])
print('Train accuracy:', 100*train_score[1])
 
test_score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', test_score[0])
print('Test accuracy:', 100*test_score[1])
# Out:
# Train loss: 0.09377577900886536
# Train accuracy: 97.24476933479309
# Test loss: 2.016954183578491
# Test accuracy: 59.65449810028076

# %%
monitor_testset_results = True

if monitor_testset_results == True:
	#make predictions for test set
	predictions = model.predict(x_test)

	index = 0
	for i in predictions:
		if index < 30 and index >= 20:
			#print(i) #predicted scores
			#print(y_test[index]) #actual scores
			
			testing_img = np.array(x_test[index], 'float32')
			testing_img = testing_img.reshape([48, 48]);
			
			plt.gray()
			plt.imshow(testing_img)
			plt.show()
			
			print(i)
			
			emotion_analysis(i)
			print("----------------------------------------------")
		index = index + 1
# Out:
# [4.8215362e-01 9.9428813e-05 3.9493782e-03 3.8515974e-03 4.9841046e-01
#  2.2907471e-04 1.1306469e-02]
# ----------------------------------------------
# [5.5354383e-09 1.4693744e-09 3.0136098e-07 1.5972718e-08 9.6980060e-08
#  9.9999940e-01 1.6495494e-07]
# ----------------------------------------------
# [8.3121455e-01 6.7931896e-06 1.8701639e-03 1.4539683e-04 1.4878273e-01
#  4.6600740e-06 1.7975675e-02]
# ----------------------------------------------
# [2.1400820e-05 7.1117302e-06 3.9832788e-03 1.9010817e-04 9.9390233e-01
#  2.0216325e-08 1.8957832e-03]
# ----------------------------------------------
# [5.1619842e-05 3.6383540e-07 1.1994536e-04 3.0617572e-03 2.7185215e-03
#  5.8225582e-05 9.9398959e-01]
# ----------------------------------------------
# [7.8366295e-02 7.9516525e-05 1.3948284e-01 9.2294859e-04 7.1117443e-01
#  1.5647827e-04 6.9817469e-02]
# ----------------------------------------------
# [1.3170028e-04 1.2391745e-06 2.3404855e-04 3.9464219e-05 1.0218269e-02
#  7.9054452e-08 9.8937523e-01]
# ----------------------------------------------
# [2.6248255e-05 1.9796735e-05 6.1687446e-01 1.2556425e-03 3.8141438e-01
#  2.8567866e-04 1.2384553e-04]
# ----------------------------------------------
# [2.7198248e-05 4.1865701e-07 5.6308749e-05 2.4848327e-06 8.1370519e-05
#  9.9710000e-01 2.7322047e-03]
# ----------------------------------------------
# [8.4139327e-09 8.2431656e-10 4.0887967e-06 3.5825056e-09 1.2422262e-07
#  9.9999547e-01 3.5191994e-07]
# ----------------------------------------------

# %%
#Confusion Matrix.

from sklearn.metrics import classification_report, confusion_matrix
 
pred_list = []; actual_list = [];
 
for i in predictions:
 
  pred_list.append(np.argmax(i))
 
for i in y_test:
 
  actual_list.append(np.argmax(i))
 
confusion_matrix(actual_list, pred_list)
# Out:
# array([[229,   7,  42,  55,  59,  13,  62],
#        [ 10,  30,   2,   2,   8,   1,   3],
#        [ 36,   3, 192,  41, 118,  28,  78],
#        [ 21,   0,  24, 737,  22,  18,  73],
#        [ 75,   1,  51,  68, 310,   7, 141],
#        [  9,   1,  39,  28,  16, 297,  25],
#        [ 53,   1,  33,  63, 107,   4, 346]])
